# %% [markdown]
# # Production ANPR Pipeline
# This notebook will set up the entire ANPR environment on Google Colab (using the T4 GPU) and launch the Gradio Web Interface.

# %% [markdown]
# ### Step 1: Clone the Repository & Install Dependencies

# %%
# !git clone https://github.com/Varun02-Sai/OCR_detection.git
# %cd OCR_detection
# !pip install -r requirements.txt
# Ensure FFmpeg is available for video conversion
# !apt-get install -y ffmpeg

# %% [markdown]
# ### Step 2: Download AI Models

# %%
# !python models/download_models.py

# %% [markdown]
# ### Step 3: Download High-Quality Test Videos
# This will download 3 short clips (Toll gate, Traffic camera, Highway) with clearly visible license plates.

# %%
# !python download_samples.py

# %% [markdown]
# ### Step 4: Launch Web Interface
# Run the cell below and click the `gradio.live` link that appears to open the UI. You can upload the videos from the `sample_videos/` folder on the left.

# %%
# !python gradio_app.py
