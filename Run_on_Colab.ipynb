# %% [markdown]
# # 🚓 Multi-Model ANPR Web Server (Google Colab)
#
# Run this notebook in Google Colab to get a free GPU and launch a public web interface for the license plate detection pipeline.
#
# ### Step 1: Ensure you are using a GPU
# Go to **Runtime > Change runtime type** in the top menu and select **T4 GPU**.

# %%
# !nvidia-smi

# %% [markdown]
# ### Step 2: Install System Dependencies for OCR

# %%
# !apt-get update
# !apt-get install -y tesseract-ocr libtesseract-dev libleptonica-dev pkg-config
# !apt-get install -y ffmpeg libsm6 libxext6  # Required for OpenCV

# %% [markdown]
# ### Step 3: Install Python Dependencies

# %%
# !pip install -r requirements.txt
# !pip install gradio paddlepaddle paddleocr pytesseract ensemble-boxes ultralytics easyocr

# %% [markdown]
# ### Step 4: Download Pretrained Models
# This pulls the fine-tuned license plate detector from Hugging Face and caches the vehicle detectors.

# %%
# !python models/download_models.py

# %% [markdown]
# ### Step 5: Launch the Web Server! 🚀
# Run the cell below. It will output a public URL (e.g., `https://xxxxxx.gradio.live`). Click that link to open your web app from anywhere!

# %%
# !python gradio_app.py
